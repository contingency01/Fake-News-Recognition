# %% [markdown]
# # Multinomial Naive Bayes Classifier
#
# **Goal:** Classify a document *d* into one of *K* classes $C_k$, given its words.
#
#
# ## 1. Bayes' Theorem
#
# $$
# P(C_k \mid d) = \frac{P(d \mid C_k) \cdot P(C_k)}{P(d)}
# $$
#
# Since  $P(d)$ is constant across classes, we use:
#
# $$
# \arg\max_{C_k} \left[ P(d \mid C_k) \cdot P(C_k) \right]
# $$
#
#
# ## 2. Multinomial Model
#
# - Represent document *d* as a vector of word counts:
# - $ d = n_1, n_2, \dots, n_V $
# - $V$ is the size of the vocabulary.
# - $n_i$ is the number of times word $w_i$ appears in document *d*.
#
# $$
# P(d \mid C_k) = \frac{N_d!}{\prod_{i=1}^{V} n_i!} \prod_{i=1}^{V} \left( P(w_i \mid C_k) \right)^{n_i}
# $$
#
# In practice, we ignore the multinomial coefficient and compute:
#
# $$
# \log P(d \mid C_k) = \sum_{i=1}^{V} n_i \cdot \log P(w_i \mid C_k)
# $$
#
#
# ## 3. Priors
#
# $$
# P(C_k) = \frac{\text{Number of documents in class } C_k}{\text{Total number of documents}}
# $$
#
#
# ## 4. Likelihoods with Smoothing
#
# $$
# P(w_i \mid C_k) = \frac{N_{ik} + \alpha}{N_k + \alpha V}
# $$
#
# Where:
#
# - $N_{ik}$ = number of times word $w_i$ occurs in documents of class $C_k$
# - $N_k$ = total number of words in documents of class $C_k$
# - $\alpha$ = smoothing parameter (usually $\alpha = 1$, Laplace smoothing)
# - $V$ = size of vocabulary
#
#
# ## 5. Prediction Rule
#
# For a given document *d*, compute for each class:
#
# $$
# \log P(C_k) + \sum_{i=1}^{V} n_i \cdot \log P(w_i \mid C_k)
# $$
#
# Choose the class with the highest score:
#
# $$
# \hat{C} = \arg\max_{C_k} \left[ \log P(C_k) + \sum_{i=1}^{V} n_i \cdot \log P(w_i \mid C_k) \right]
# $$
#
#
# ## 6. Summary of Training Steps
#
# 1. Compute $P(C_k)$ for each class.
# 2. For each word $w_i$ and each class $C_k$, compute $P(w_i \mid C_k)$ with smoothing.
#
#
# ## 7. Summary of Prediction Steps
#
# 1. For a new document *d*, compute the score for each class.
# 2. Choose the class with the highest score.

# %% [markdown]
# ---
# # Load the datasets

# %%
# Load the required libraries
library(ggplot2)
library(tidytext)
library(dplyr)

# %%
# Load the training and testing datasets
train_data = read.csv("data/train.csv")
test_data = read.csv("data/test.csv")

# %%
# Divide the training dataset into training and validation set. 20% of the data will be used for validation.

set.seed(123)  # For reproducibility

train_indices = sample(1:nrow(train_data), size = 0.8 * nrow(train_data))
train_set = train_data[train_indices, ]
validation_data = train_data[-train_indices, ]

# %%
print("--------- Training Data Summary ---------")
summarize(train_data,
          num_rows = n(), 
          num_cols = ncol(train_data),
          num_missing = sum(is.na(train_data)))

print("--------- Validation Set Summary ---------")
summarise(validation_data,
          num_rows = n(),
          num_cols = ncol(validation_data),
          num_missing = sum(is.na(validation_data)))

print("--------- Testing Data Summary ---------")
summarise(test_data,
          num_rows = n(),
          num_cols = ncol(test_data),
          num_missing = sum(is.na(test_data)))
# Out:
# [1] "--------- Training Data Summary ---------"
#   num_rows num_cols num_missing
# 1 10240    3        0
# [1] "--------- Validation Set Summary ---------"
#   num_rows num_cols num_missing
# 1 2048     3        0
# [1] "--------- Testing Data Summary ---------"
#   num_rows num_cols num_missing
# 1 1267     2        0

# %%
train_set = train_set %>% mutate(doc_id = row_number())
validation_data = validation_data %>% mutate(doc_id = row_number())
test_data = test_data %>% mutate(doc_id = row_number())

# %%
train_set$Text = as.character(train_set$Text)
validation_data$Text = as.character(validation_data$Text)
test_data$Text = as.character(test_data$Text)

# %%
train_set
# Out:
#      Labels
# 1    4
# 2    5
# 3    5
# 4    3
# 5    5
# 6    1
# 7    1
# 8    2
# 9    1
# 10   5
# 11   2
# 12   1
# 13   5
# 14   4
# 15   2
# 16   5
# 17   3
# 18   2
# 19   2
# 20   1
# 21   0
# 22   2
# 23   3
# 24   5
# 25   1
# 26   3
# 27   5
# 28   1
# 29   1
# 30   1
# ...  ...
# 8163 3
# 8164 1
# 8165 1
# 8166 0
# 8167 0
# 8168 4
# 8169 3
# 8170 4
# 8171 5
# 8172 1
# 8173 3
# 8174 2
# 8175 1
# 8176 5
# 8177 0
# 8178 2
# 8179 5
# 8180 0
# 8181 1
# 8182 3
# 8183 5
# 8184 5
# 8185 0
# 8186 5
# 8187 2
# 8188 3
# 8189 3
# 8190 2
# 8191 3
# 8192 4
#      Text
# 1    Says Wisconsin Gov. Scott Walkers budget calls for raising property taxes by nearly $500 billion.
# 2    Californias credit rating is the worst in the country.
# 3    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 4    Palin "fired Wasilla's Police Chief because he 'intimidated' her."
# 5    [L]ess than one-tenth of Atlantas transportation needs are covered in a referendum to levy a 1-cent sales tax.
# 6    Im the only candidate for governor whos rolled out any policies so far.
# 7    Said U.S. Rep. Jim Marshall, D-Macon, sent nearly $2 billion overseas to build wind turbines and create jobs, mostly in China
# 8    In Wisconsin, Gov. Scott Walker has created a manufacturing-led jobs recovery. 30,000 new jobs were created this year, with 15,000 created in the struggling manufacturing sector.
# 9    Today there are more men and women out of work in America than there are people working in Canada.
# 10   Wayne Powell has a stated position of having no objection to taking `In God We Trust off of U.S. currency.
# 11   Missouri is the state with the lowest paid workers.
# 12   The Justice Departments Fast and Furious gun-walking program started in the Bush administration.
# 13   The hole in the earth thats going to be dug (for the proposed Gogebic mine) is bigger than my entire district.
# 14   If Buehler were elected, our vote-by-mail system would be at risk.
# 15   Says Texas leads the nation in fatal industrial accidents.
# 16   Countries bombed: Obama 7, Bush 4
# 17   Says Donald Trump said the U.S. should encourage Japan to get nuclear weapons.
# 18   One out of four corporations doesnt pay a nickel in (federal income) taxes.
# 19   Says that in 2009, Jon Huntsman said that the Recovery Act wasnt large enough and as governor he asked for $14.4 billion in federal stimulus funds. Now hes saying that he never supported it.
# 20   1.3-million people in America make their living off eBay.
# 21   Because George Holding doesnt live in the congressional district hes running for, he doesnt experience the same things that we are all experiencing.
# 22   Twenty-five percent of people in the country have said they changed their email and phone habits because of the collection of data allowed by the Patriot Act.
# 23   Right now, 50 percent of Florida students leaving high school cannot read at grade level.
# 24   New Jersey has the highest property taxes in the nation and not by a little. They are the highest property taxes in the nation, more than double the national average.
# 25   When the Affordable Care Act was signed, 17 million American children had a pre-existing condition and were uninsurable.
# 26   Over the past decade, the big five oil companies --- BP, Chevron, ConocoPhillips, ExxonMobil and Shell -- made a total profit of nearly $1 trillion.
# 27   In 2010, Mr. [Anthony] Gemma described himself as a pro-life candidate. Now, he claims to be pro-choice.
# 28   No one thought we could get a bipartisan bill (Medicaid) passed. We did in the Florida Senate.
# 29   Says Planned Parenthood provides about 140 visits for prenatal care in each state.
# 30   A recent drop in the unemployment rate is questionable because it was calculated over two days of the Thanksgiving week.
# ...  ...
# 8163 United States of America is twenty-sixth in school performance in the world.
# 8164 Gas prices have never been higher, and Exxon Mobil's profits have never been higher.
# 8165 Obama plans "a tax increase for everyone earning more than $42,000 a year."
# 8166 President Obamas budget would call for about $25 trillion in debt by the end of his term, if he was re-elected.
# 8167 Georgia has had 12 school shootings in the two years since the mass killing at Sandy Hook Elementary School, more than any other state.
# 8168 Says the Texas State Board of Education is considering eliminating references to Christmas and the Constitution in textbooks.
# 8169 Says Jeanne Shaheen has voted with the president 99 percent of the time.
# 8170 Far more children died last year drowning in their bathtubs than were killed accidentally by guns.
# 8171 The Associated Press called Charlie Crist's attacks "over the top," "out of context," and "not true."
# 8172 Says Mahmoud Ahmadinejad said that if he has a nuclear weapon he will use it to wipe Israel off the face of the earth. He will use it against the United States of America.
# 8173 Since the United States began negotiations with Iran, thats probably the first year and a half in which Iran has not advanced its nuclear program in the last decade.
# 8174 Less than two years ago, we made a commitment to repay the U.S. . . .taxpayers in full, and today we made good on that promise.
# 8175 TheAffordable Care Actalters the sensible doctor-patient-relationship-centered health care program ... we see today.
# 8176 With one stroke of his pen, President Bush has denied health insurance to 3.8 million kids who were due to get it under this bipartisan expansion of the Children's Health Insurance Program.
# 8177 Says Obama has doubled the stock market from where we started when he was sworn into office
# 8178 Thanks to our policies, for the first time in state history, we have put millions of dollars into our rainy day fund in consecutive years.
# 8179 Says hes the first Aggie governor of Texas.
# 8180 Since 1978, California has spent $5 billion to put 13 people to death.
# 8181 Obamacare adds trillions to our deficits and to our national debt.
# 8182 The United States is behind many countries in Europe in terms of the ability of every kid in America to get ahead.
# 8183 Says the Multnomah County Library system is the second busiest in the nation.
# 8184 Says he was known as Veto Corleone for cutting spending as Florida governor.
# 8185 Female students at UVA have a 20 percent chance of being sexually assaulted.
# 8186 The U.S. unemployment rate has remained above 8 percent for 43 consecutive months, the longest stretch since the Great Depression.
# 8187 President Barack Obamas spending drove us $5 trillion deeper in debt.
# 8188 Between 40 and 50 percent of tax filers do not owe any income tax.
# 8189 Kilmartin has helped pass laws to create a witness protection program.
# 8190 Israel has seen a 90 percent reduction in terrorist attacks that it attributes to building a 500-mile fence.
# 8191 New Jersey has lost over half of our pharmaceutical jobs to states you know, not low-tax states like in the South, but high-tax states like New York.
# 8192 The Senate voted this week to allow illegal aliens access to Social Security benefits.
#      Text_Tag                                                     doc_id
# 1    state-budget,taxes                                            1
# 2    economy,message-machine,state-budget                          2
# 3    taxes                                                         3
# 4    crime                                                         4
# 5    transportation                                                5
# 6    elections                                                     6
# 7    environment,message-machine,stimulus                          7
# 8    jobs,message-machine-2012                                     8
# 9    economy,workers                                               9
# 10   religion                                                     10
# 11   economy,jobs,poverty,workers                                 11
# 12   guns                                                         12
# 13   environment                                                  13
# 14   elections,message-machine-2012                               14
# 15   labor                                                        15
# 16   foreign-policy,military                                      16
# 17   foreign-policy,nuclear                                       17
# 18   taxes                                                        18
# 19   economy,new-hampshire-2012,stimulus                          19
# 20   economy                                                      20
# 21   congress,debates,redistricting                               21
# 22   civil-rights,homeland-security,terrorism                     22
# 23   education                                                    23
# 24   taxes                                                        24
# 25   children,families,health-care                                25
# 26   corporations,energy,taxes                                    26
# 27   abortion,candidates-biography,health-care,legal-issues,women 27
# 28   health-care,medicare,state-budget                            28
# 29   health-care                                                  29
# 30   economy,pundits,workers                                      30
# ...  ...                                                          ...
# 8163 education                                                    8163
# 8164 corporations,energy                                          8164
# 8165 taxes                                                        8165
# 8166 deficit,federal-budget                                       8166
# 8167 children,education,guns,public-safety                        8167
# 8168 education                                                    8168
# 8169 bipartisanship                                               8169
# 8170 guns                                                         8170
# 8171 candidates-biography                                         8171
# 8172 foreign-policy,israel,nuclear                                8172
# 8173 foreign-policy,nuclear                                       8173
# 8174 corporations,financial-regulation,market-regulation          8174
# 8175 health-care                                                  8175
# 8176 health-care                                                  8176
# 8177 bush-administration,economy,jobs,stimulus                    8177
# 8178 state-budget                                                 8178
# 8179 education                                                    8179
# 8180 crime,criminal-justice,death-penalty                         8180
# 8181 federal-budget,health-care                                   8181
# 8182 economy                                                      8182
# 8183 taxes                                                        8183
# 8184 state-budget                                                 8184
# 8185 crime,public-safety                                          8185
# 8186 jobs                                                         8186
# 8187 debt,deficit,economy,federal-budget,message-machine-2012     8187
# 8188 taxes                                                        8188
# 8189 candidates-biography,crime                                   8189
# 8190 foreign-policy,israel,terrorism                              8190
# 8191 jobs                                                         8191
# 8192 immigration                                                  8192

# %% [markdown]
# # Tokenization
# We tokenize all of the datasets such that each datapoint will be a vector of the words it contains. All of the letters are converted into lowercase. The punctuation is removed. Stopwords such as "and", "of", or "the" are also removed.

# %%
tokenize_and_clean_text <- function(data_frame) {
  data_frame %>%
    unnest_tokens(word, Text, drop = FALSE) %>%
    # Remove punctuation
    mutate(word = gsub("[[:punct:]]", "", word)) %>%
    # Remove numbers
    mutate(word = gsub("[[:digit:]]", "", word)) %>%
    # Remove English stopwords
    anti_join(stop_words, by = "word") %>%
    # Filter out any empty strings
    filter(word != "") %>%
    # Filter out single-character words
    filter(nchar(word) > 1)
}

# %%
tokenized_train_set = tokenize_and_clean_text(train_set)
tokenized_test_data = tokenize_and_clean_text(test_data)
validation_data = tokenize_and_clean_text(validation_data)

# %%
tokenized_train_set
# Out:
#       Labels
# 1     4
# 2     4
# 3     4
# 4     4
# 5     4
# 6     4
# 7     4
# 8     4
# 9     4
# 10    4
# 11    5
# 12    5
# 13    5
# 14    5
# 15    5
# 16    5
# 17    5
# 18    5
# 19    5
# 20    5
# 21    5
# 22    5
# 23    5
# 24    5
# 25    5
# 26    5
# 27    5
# 28    5
# 29    3
# 30    3
# ...   ...
# 69521 3
# 69522 3
# 69523 2
# 69524 2
# 69525 2
# 69526 2
# 69527 2
# 69528 2
# 69529 2
# 69530 2
# 69531 2
# 69532 3
# 69533 3
# 69534 3
# 69535 3
# 69536 3
# 69537 3
# 69538 3
# 69539 3
# 69540 3
# 69541 3
# 69542 4
# 69543 4
# 69544 4
# 69545 4
# 69546 4
# 69547 4
# 69548 4
# 69549 4
# 69550 4
#       Text
# 1     Says Wisconsin Gov. Scott Walkers budget calls for raising property taxes by nearly $500 billion.
# 2     Says Wisconsin Gov. Scott Walkers budget calls for raising property taxes by nearly $500 billion.
# 3     Says Wisconsin Gov. Scott Walkers budget calls for raising property taxes by nearly $500 billion.
# 4     Says Wisconsin Gov. Scott Walkers budget calls for raising property taxes by nearly $500 billion.
# 5     Says Wisconsin Gov. Scott Walkers budget calls for raising property taxes by nearly $500 billion.
# 6     Says Wisconsin Gov. Scott Walkers budget calls for raising property taxes by nearly $500 billion.
# 7     Says Wisconsin Gov. Scott Walkers budget calls for raising property taxes by nearly $500 billion.
# 8     Says Wisconsin Gov. Scott Walkers budget calls for raising property taxes by nearly $500 billion.
# 9     Says Wisconsin Gov. Scott Walkers budget calls for raising property taxes by nearly $500 billion.
# 10    Says Wisconsin Gov. Scott Walkers budget calls for raising property taxes by nearly $500 billion.
# 11    Californias credit rating is the worst in the country.
# 12    Californias credit rating is the worst in the country.
# 13    Californias credit rating is the worst in the country.
# 14    Californias credit rating is the worst in the country.
# 15    Californias credit rating is the worst in the country.
# 16    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 17    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 18    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 19    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 20    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 21    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 22    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 23    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 24    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 25    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 26    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 27    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 28    Michael Thurmond authored major legislation that has provided more than $250 million in tax relief to Georgias senior citizens and working families.
# 29    Palin "fired Wasilla's Police Chief because he 'intimidated' her."
# 30    Palin "fired Wasilla's Police Chief because he 'intimidated' her."
# ...   ...
# 69521 Kilmartin has helped pass laws to create a witness protection program.
# 69522 Kilmartin has helped pass laws to create a witness protection program.
# 69523 Israel has seen a 90 percent reduction in terrorist attacks that it attributes to building a 500-mile fence.
# 69524 Israel has seen a 90 percent reduction in terrorist attacks that it attributes to building a 500-mile fence.
# 69525 Israel has seen a 90 percent reduction in terrorist attacks that it attributes to building a 500-mile fence.
# 69526 Israel has seen a 90 percent reduction in terrorist attacks that it attributes to building a 500-mile fence.
# 69527 Israel has seen a 90 percent reduction in terrorist attacks that it attributes to building a 500-mile fence.
# 69528 Israel has seen a 90 percent reduction in terrorist attacks that it attributes to building a 500-mile fence.
# 69529 Israel has seen a 90 percent reduction in terrorist attacks that it attributes to building a 500-mile fence.
# 69530 Israel has seen a 90 percent reduction in terrorist attacks that it attributes to building a 500-mile fence.
# 69531 Israel has seen a 90 percent reduction in terrorist attacks that it attributes to building a 500-mile fence.
# 69532 New Jersey has lost over half of our pharmaceutical jobs to states you know, not low-tax states like in the South, but high-tax states like New York.
# 69533 New Jersey has lost over half of our pharmaceutical jobs to states you know, not low-tax states like in the South, but high-tax states like New York.
# 69534 New Jersey has lost over half of our pharmaceutical jobs to states you know, not low-tax states like in the South, but high-tax states like New York.
# 69535 New Jersey has lost over half of our pharmaceutical jobs to states you know, not low-tax states like in the South, but high-tax states like New York.
# 69536 New Jersey has lost over half of our pharmaceutical jobs to states you know, not low-tax states like in the South, but high-tax states like New York.
# 69537 New Jersey has lost over half of our pharmaceutical jobs to states you know, not low-tax states like in the South, but high-tax states like New York.
# 69538 New Jersey has lost over half of our pharmaceutical jobs to states you know, not low-tax states like in the South, but high-tax states like New York.
# 69539 New Jersey has lost over half of our pharmaceutical jobs to states you know, not low-tax states like in the South, but high-tax states like New York.
# 69540 New Jersey has lost over half of our pharmaceutical jobs to states you know, not low-tax states like in the South, but high-tax states like New York.
# 69541 New Jersey has lost over half of our pharmaceutical jobs to states you know, not low-tax states like in the South, but high-tax states like New York.
# 69542 The Senate voted this week to allow illegal aliens access to Social Security benefits.
# 69543 The Senate voted this week to allow illegal aliens access to Social Security benefits.
# 69544 The Senate voted this week to allow illegal aliens access to Social Security benefits.
# 69545 The Senate voted this week to allow illegal aliens access to Social Security benefits.
# 69546 The Senate voted this week to allow illegal aliens access to Social Security benefits.
# 69547 The Senate voted this week to allow illegal aliens access to Social Security benefits.
# 69548 The Senate voted this week to allow illegal aliens access to Social Security benefits.
# 69549 The Senate voted this week to allow illegal aliens access to Social Security benefits.
# 69550 The Senate voted this week to allow illegal aliens access to Social Security benefits.
#       Text_Tag                             doc_id word
# 1     state-budget,taxes                   1      wisconsin
# 2     state-budget,taxes                   1      gov
# 3     state-budget,taxes                   1      scott
# 4     state-budget,taxes                   1      walkers
# 5     state-budget,taxes                   1      budget
# 6     state-budget,taxes                   1      calls
# 7     state-budget,taxes                   1      raising
# 8     state-budget,taxes                   1      property
# 9     state-budget,taxes                   1      taxes
# 10    state-budget,taxes                   1      billion
# 11    economy,message-machine,state-budget 2      californias
# 12    economy,message-machine,state-budget 2      credit
# 13    economy,message-machine,state-budget 2      rating
# 14    economy,message-machine,state-budget 2      worst
# 15    economy,message-machine,state-budget 2      country
# 16    taxes                                3      michael
# 17    taxes                                3      thurmond
# 18    taxes                                3      authored
# 19    taxes                                3      major
# 20    taxes                                3      legislation
# 21    taxes                                3      provided
# 22    taxes                                3      million
# 23    taxes                                3      tax
# 24    taxes                                3      relief
# 25    taxes                                3      georgias
# 26    taxes                                3      senior
# 27    taxes                                3      citizens
# 28    taxes                                3      families
# 29    crime                                4      palin
# 30    crime                                4      fired
# ...   ...                                  ...    ...
# 69521 candidates-biography,crime           8189   protection
# 69522 candidates-biography,crime           8189   program
# 69523 foreign-policy,israel,terrorism      8190   israel
# 69524 foreign-policy,israel,terrorism      8190   percent
# 69525 foreign-policy,israel,terrorism      8190   reduction
# 69526 foreign-policy,israel,terrorism      8190   terrorist
# 69527 foreign-policy,israel,terrorism      8190   attacks
# 69528 foreign-policy,israel,terrorism      8190   attributes
# 69529 foreign-policy,israel,terrorism      8190   building
# 69530 foreign-policy,israel,terrorism      8190   mile
# 69531 foreign-policy,israel,terrorism      8190   fence
# 69532 jobs                                 8191   jersey
# 69533 jobs                                 8191   lost
# 69534 jobs                                 8191   half
# 69535 jobs                                 8191   pharmaceutical
# 69536 jobs                                 8191   jobs
# 69537 jobs                                 8191   low
# 69538 jobs                                 8191   tax
# 69539 jobs                                 8191   south
# 69540 jobs                                 8191   tax
# 69541 jobs                                 8191   york
# 69542 immigration                          8192   senate
# 69543 immigration                          8192   voted
# 69544 immigration                          8192   week
# 69545 immigration                          8192   illegal
# 69546 immigration                          8192   aliens
# 69547 immigration                          8192   access
# 69548 immigration                          8192   social
# 69549 immigration                          8192   security
# 69550 immigration                          8192   benefits
